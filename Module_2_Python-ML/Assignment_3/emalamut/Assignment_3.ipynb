# %% [markdown]
# # **Assignment 3** - Introduction to Machine Learning: Regression
# #### **Author**: Shakthi Visagan
# #### **Purpose**: Introduction to machine learning and how to think like a machine learning engineer
#
# Machine learning is the study of how to extract insights from data. Data on its own is largely useless, and arguably of negative value, as it takes time, effort, and money to collect, store, and maintain. However, manipulating data to yield deeper generalizations about the data itself has proven to be a greatly lucrative occupation. A simple Google search will reveal the salaries of those who spend their time creating machine learning models. Though machine learning is marketed as a modern advance, it has its roots and foundation in the mathematics and engineering developed by mythic legends like Euler, Gauss, Legendre, and their ilk. Regardless, machine learning owes its current capitalistic success and popularity mainly to the manifestation of Moore's law and the ability to collect and process unfathomable amounts of data. Some examples of the uses of machine learning are sabremetrics, the use of data-based insights to improve the performance of athletes and sports teams, econometrics, the use of financial and economical data to drive public policy, and neuro-engineering, the use of machine learning to process the neural signals of the brain to create a two-way interface between a prosthetic machine and the brain. This is by no means a comprehensive list, and you are encouraged to look into areas where machine learning is being used and find your own interests.
#
# I personally enjoy reading the [technical blog at Stitch Fix](https://multithreaded.stitchfix.com/blog/), where they're using machine learning to design and customize outfits. Turns out, this is a harder computational task than it looks.
#
# Be resourceful as you complete this assignment (the Internet is the sum of all human knowledge (supposedly)).

# %% [markdown]
# ---

# %% [markdown]
# #### (1) Define, compare, and give possible real world examples for the the following terms:
# 1. Regression and Classification
# 2. Discrete distribution (variable) and Continuous distribution (variable)
# 3. Supervised learning and Unsupervised learning (sometimes called Semi-supervised learning)
# 4. Linear function and Nonlinear function
#
# Write your answers below.

# %% [markdown]
# Regression and Classification - predicting a quantity (how much my house will sell for) vs predicting a class label (house sells or does not sell)
# Discrete distribution (variable) and Continuous distribution (variable) - discrete = finite values (ie. monte carlo), continuous = infinite measureable values (ie. height)
# Supervised learning and Unsupervised learning (sometimes called Semi-supervised learning) - given inputs and outputs, come up with a function that approximates the relation vs given some labeled data and some unlabeled data, make both classification and learn structure
# Linear function and Nonlinear function - no exponenets larger than one (straight line) vs exponents can be larger than one (curved line)

# %% [markdown]
# ---

# %%
### DON'T EDIT THIS CODE ###
import numpy as np
from matplotlib import gridspec, pyplot as plt
# %matplotlib inline
plt.rc('font', **{'family': 'sans-serif', 'size': 10})
# for Palatino and other serif fonts use:
# rc('font',**{'family':'serif','serif':['Palatino']})
plt.rc('xtick', **{'labelsize': 'medium'})
plt.rc('ytick', **{'labelsize': 'medium'})
import seaborn as sns
df = sns.load_dataset("anscombe")
print(df)

x0=df.loc[ 0:10]["x"][:].tolist()
x1=df.loc[11:21]["x"][:].tolist()
x2=df.loc[22:32]["x"][:].tolist()
x3=df.loc[33:43]["x"][:].tolist()
y0=df.loc[ 0:10]["y"][:].tolist()
y1=df.loc[11:21]["y"][:].tolist()
y2=df.loc[22:32]["y"][:].tolist()
y3=df.loc[33:43]["y"][:].tolist()
list_of_xs = [x0,x1,x2,x3]
list_of_ys = [y0,y1,y2,y3]
colors=['r','b','g','y']


f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(list_of_xs[i], list_of_ys[i], edgecolors='k', marker="o", c=colors[i], alpha=2./3)
plt.tight_layout()
plt.show()
### DON'T EDIT THIS CODE ###
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### (2) Exploratory Data Analysis
#
# You'll be using the datasets above to begin your foray into machine learning. The datasets are organized in the following way: you have four sets of eleven data points each. The eleven data points are in $x$ and $y$ coordinates and are contained in the lists $x_{0}, y_{0}$, $x_{1}, y_{1}$, $x_{2}, y_{2}$, $x_{3}, y_{3}$. They are graphed aboved for you. Look at the plotting code to see how the lists are related, and which lists contain what data points.
#
# Every one of your machine learning projects, be it in academic research or in industrial research, will begin with _exploratory data analysis_. This analysis is where you figure out what your data looks like, what types of models will give you the most insight, and if there is any preprocessing your data requires.

# %% [markdown]
# (2a) If I want to fit straight lines to these data such that given a new data $x$-coordinate, $x^{*}$, I can find a $y^{*}$ on that straight line that resembles the data that the line travels through, which terms from problem (1) best describe my goals?
#
# Write your answer below.

# %% [markdown]
# regression, continuous distribution, supervised learning, linear function,

# %% [markdown]
# (2b) For each of the $x$ lists (the lists of the $x$-coordinates), find the following:
# 1. the sample mean or average
# 2. the sample variance
# 3. the sample standard deviation
#
# Do the same for each of the $y$ lists (the lists of the $y$-coordinates).
#
# Write your code and answers as comments below.

# %%
def stats(array):
    stats = []; #stores mean, variance, and std
    stats.append(array.mean())
    stats.append(array.var())
    stats.append(array.std())
    return stats

x0=df.loc[ 0:10]["x"][:]
x1=df.loc[11:21]["x"][:]
x2=df.loc[22:32]["x"][:]
x3=df.loc[33:43]["x"][:]
y0=df.loc[ 0:10]["y"][:]
y1=df.loc[11:21]["y"][:]
y2=df.loc[22:32]["y"][:]
y3=df.loc[33:43]["y"][:]


lists = [x0,x1,x2,x3,y0,y1,y2,y3]

for i in lists:
    print(stats(i))
# Out:
# [9.0, 11.0, 3.3166247903554]
# [9.0, 11.0, 3.3166247903554]
# [9.0, 11.0, 3.3166247903554]
# [9.0, 11.0, 3.3166247903554]
# [7.500909090909093, 4.127269090909091, 2.031568135925815]
# [7.500909090909091, 4.127629090909091, 2.0316567355016177]
# [7.500000000000001, 4.12262, 2.030423601123667]
# [7.50090909090909, 4.12324909090909, 2.0305785113876023]

# %% [markdown]
# (2c) Is there anything suspicious about the means and the other descriptive statistics you've found about the data relative to what the data look like?
#
# Write your answer below.

# %% [raw]
# the statistics are all the same for every graph, but the graphs look very different

# %% [markdown]
# (2d) Look up how to calculate the sample correlation coefficient using `numpy`. It should be one function and should only take one $x$ and one $y$ argument, the pairs of lists. Your output should be a matrix. Do this for each pair of lists $x_{i},y_{i}$ for $i\in\{0,1,2,3\}$. Are the correlations across the different data the same? Correlation (measured through the Pearson Correlation Coefficient) is a measure of linearity. Which of the datasets presented above make the correlation you've just calculated an irrelevant measure for the data (hint: which data set has nonlinear relationships, or no relationships between the $x$ and $y$ data?)
#
# Write your code and answers as comments below.

# %%
print(np.corrcoef(x0,y0))
print(np.corrcoef(x1,y1))
print(np.corrcoef(x2,y2))
print(np.corrcoef(x3,y3))
#all of them are nonlinear?
# Out:
# [[1.         0.81642052]
#  [0.81642052 1.        ]]
# [[1.         0.81623651]
#  [0.81623651 1.        ]]
# [[1.         0.81628674]
#  [0.81628674 1.        ]]
# [[1.         0.81652144]
#  [0.81652144 1.        ]]

# %% [markdown]
# ---

# %% [markdown]
# #### (3) Simple Linear Regression
#
# Undergraduate: Everything is linear!
#
# Graduate: Everything is nonlinear...
#
# Deathbed: Everything is locally linear.
#
# As you go through this problem and the following assignments, this adage will make more sense.

# %% [markdown]
# (3a) Let's make the assumption that the data is linear. What this means is that we are assuming the underlying phenomenon that is generating the data is linear. You should become familiar with the notion that the data you see is _representative_ of an underlying phenomenon or population and is not actually the _true_ phenomenon (this is why we associate the data and the statistics we calculate on them with the word _sample_). Is the linear assumption valid for the four datasets? If the data were perfectly linearly correlated then all we’d have to do is take any two points from the data sets, calculate the slope, $\beta_{1}$ and then using the slope calculate the $y$-intercept, $\beta_{0}$, and we’d get a line of the form $$\beta_{0}+\beta_{1}\mathbf{x} = \mathbf{y} \tag{1}$$ This process should be familiar to you. However, it's clear that the data isn't perfectly linearly correlated. Nevertheless, we do know that any two points create a line. Let's create three lines that pass through the data using the fact that any two points define a line:
# 1. find and plot the lines for the datasets that connect the first data point and the mean of the data points (recall that the mean of the set of points is just the mean of the $x$-elements and the mean of the $y$-elements)
# 2. find and plot the lines for the datasets that connect the first and last data point
# 3. find and plot the lines for the datasets that connect the mean of the data points and the last data point
#
# You should be using list slicing and indexing throughout your calculations/plotting. Python makes it easy to access first/last elements of a list. Python also makes it easy to calculate the mean of a list. The first and last data point aren't necessarily the smallest and largest values, respectively, for $x$ and $y$ in the dataset.
#
# Write your code below. Show all three lines on the four subplots in one plot similar to the one above. The first line (the line that goes through the first data point and the mean of the data is already done for you). The plotting code is already done for you.

# %%
# line 1 coefficients: through the 1st point and the mean
beta_1_1 = []
beta_0_1 = []
for i in range(4):
    y = list_of_ys[i]
    x = list_of_xs[i]
    beta_1_1.append( ((sum(y)/len(y)) - y[0])/((sum(x)/len(x)) - x[0]) ) #slope
    beta_0_1.append( y[0] - beta_1_1[i]*x[0] ) #y intercept
    assert beta_1_1[i]*x[0]+beta_0_1[i] == y[0]

# line 2 coefficients: through the 1st point and the last point
beta_1_2 = []
beta_0_2 = []
for i in range(4):
    y = list_of_ys[i]
    x = list_of_xs[i]
    # write code to calculate the coefficients
    ### Write code below
    #beta_1_2.append(((y[-1] - y[0])/(x[-1] - x[0])))
    #beta_0_2.append( y[0] - beta_1_2[i]*x[0])
    # Uncomment the assert when you're done
    ### Write code above ###
    #assert beta_1_2[i]*x[0]+beta_0_2[i] == y[0]

# line 3 coefficients: through the mean and the last point
beta_1_3 = []
beta_0_3 = []
for i in range(4):
    y = list_of_ys[i]
    x = list_of_xs[i]
    # write code to calculate the coefficients
    ### Write code below
    beta_1_3.append( (y[-1] - (sum(y)/len(y)))/( x[-1] - (sum(x)/len(x))) )
    beta_0_3.append(((sum(y)/len(y))) - beta_1_3[i]*(sum(x)/len(x)))
    # Uncomment the assert when you're done
    ### Write code above ###
    assert beta_1_3[i]*x[-1]+beta_0_3[i] == y[-1]

# %%
### The plotting code below should execute ###
f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(list_of_xs[i], list_of_ys[i], edgecolors='k', marker="o", c=colors[i], alpha=2./3)
    tmp_x = np.linspace(0,20)
    # line 1: through the 1st point and the mean
    ax[i].plot(tmp_x, beta_0_1[i]+beta_1_1[i]*tmp_x, 'k-', alpha=2./3, label='1')    
    # line 2: through the 1st point and the last point
    #ax[i].plot(tmp_x, beta_0_2[i]+beta_1_2[i]*tmp_x, 'k--', alpha=2./3, label='2')    
    # line 1: through the mean and the last point
    ax[i].plot(tmp_x, beta_0_3[i]+beta_1_3[i]*tmp_x, 'k-.', alpha=2./3, label='3')
plt.legend()
plt.tight_layout()
plt.show()
### No changes are required for the plotting code ###

# %% [markdown]
# (3b) Which of the lines does the "best" at fitting the data? Would you stop after this analysis (do you think you can do a better job in fitting the lines)? Consider that your defintion of what "best" means isn't rigorously defined. What would the "best" line do in terms of fitting the data the "best"?
#
# Write your answers below. No code required.

# %% [markdown]
# fits the data that's already basically linear. Not so good at the other ones

# %% [markdown]
# (3c) As we know, our data are *NOT* aligned in a perfectly linearly correlated manner. However, the "best" line would have coefficients $\beta_0$ and $\beta_1$ that fit well for all the points regardless.
#
# Why don’t try to find values for $\beta_0$ and $\beta_1$ that work for _all_ our points in our set, and not just one or two of them; that is, let’s try to solve the following system of equations:
# $$\begin{align} \beta_0+\beta_1 x^1 &= y^1 \\ \beta_0+\beta_1 x^2 &= y^2 \\ \vdots \\ \beta_0+\beta_1 x^m &= y^m \end{align} \tag{2}$$
#
# NOTE: $k\in\{1,2,\ldots,m\}$ is not an exponent! It is an iterator over the data points or the indices of the lists.
#
# This is an *over-determined* system of equations (we have more equations than we have variables) because we're trying to find a line that passes through more than two points. Observe the following image
#
# ![residuals](images/residuals.png)
#
# If our goal is to find the best possible red line, then the _distance_ from the blue data points to the red line must be as _small_ as possible for _each point_, to ensure that we have properly tried to fit all of our data. Now observe the distances; it seems like the data point is some distance _vertically_ further away, that is, in the direction of the $y$-axis. Mathematically, we need to _minimize the distance between our observed data (blue dots) and our predicted data (our line)_. We’ll call the distance $$\mathbf R^{k} = y_{\mathrm{observed}}^{k} - y_{\mathrm{predicted}}^{k}=y_{\mathrm{observed}}^{k}-(\beta_{0}+\beta_{1}x_{\mathrm{observed}}^{k}) \tag{3} $$ This is called the _residual_ for each data point, where $k$ is an iterator over the datapoints. Because we want to minimize the distance for all of them, we’ll just _add_ all the $\mathbf R^{k}$ from $k=0,1,2,\ldots,m$ and then minimize the *sum*. However, this problem arises a lot in probability and the fact is that
# $$ \sum_{k=1}^m \mathbf R^{k}=\sum_{k=1}^m (y_{\mathrm{observed}}^{k} - y_{\mathrm{predicted}}^{k})= \sum_{k=1}^m (y_{\mathrm{observed}}^{k}-(\beta_{0}+\beta_{1}x_{\mathrm{observed}}^{k}))=0 \tag{4}$$
# **always**. Let's show a simpler version of this through code.
#
# Take your $y$ and $x$ lists and show that subtracting each element in them by the mean of their lists and taking the sum of the differences evaluates to some really small number. Show that the mean of the differences is a small number. Do you have an explanation for why this happens? (hint: if you have some distribution of data, and you shift the data by the mean, what is the new mean of the shifted data?)
#
# Write your code and answers as comments below.

# %%
for i in range(4):
    y = np.asarray(list_of_ys[i])
    x = np.asarray(list_of_xs[i])
    mean_y = y.mean()
    mean_x = x.mean()
    sum_x = 0
    sum_y = 0
    for j in range(np.size(y)):
        sum_y = sum_y + (y[j] - mean_y)
        sum_x = sum_x + (x[j] - mean_x)
    print(sum_y)
    print(sum_x)

#shifting all data by the mean, doesn't change anything about the distribution of the data, mean - mean
# Out:
# -1.9539925233402755e-14
# 0.0
# 9.769962616701378e-15
# 0.0
# 0.0
# 0.0
# -8.881784197001252e-16
# 0.0

# %% [markdown]
# (3d) So it seems like minimizing the residuals as defined above won't really help. Also note that minimizing the sum of residuals with respect to the $\beta$ coefficients doesn't really tell us anything about those coefficients. The way to alleviate this is to take the _square_ of the residuals. So in this case we’re no longer interested in minimizing $\sum \mathbf R^k$ but rather in minimizing $\sum (\mathbf{R}^k)^2$
#
# $$ \sum_{k=1}^m (\mathbf{R}^k)^2=\sum_{k=1}^m (y_{\mathrm{observed}}^k - y_{\mathrm{predicted}}^k)^2=\sum_{k=1}^m(y^k-(\beta_0+\beta_1 x^k))^2=\sum_{k=1}^m(y^k-\beta_0-\beta_1 x^k)^2=S(\beta_{0},\beta_{1}) \tag{5}$$
#
# Minimizing $S(\beta_0,\beta_1)$ with respect to the $\beta$ parameters according to the values of the observed data $(x^k,y^k)$ for $k\in\{1,2,\ldots,m\}$ will then yield the line of best fit.
#
# What we've arrived at is the formulation known as _least squares_. This method first gained popularity in the late 18th, early 19th century, as they were used by Gauss and Legendre for analyzing the motion and orbits of planets.
#
# Our problem is evaluate now the following: $$\min_{\beta_{0},\beta_{1}}S(\beta_{0},\beta_{1})=\min_{\beta_{0},\beta_{1}}\sum_{k=1}^m (\mathbf{R}^k)^2=\min_{\beta_{0},\beta_{1}}\sum_{k=1}^m(y^k-\beta_0-\beta_1 x^k)^2 \tag{6}$$
#
# Recall from introductory calculus and physics how to find the minimum of a function with respect to an argument (recall how one would find the time of maximal height of a ball tossed upwards given its position as a function of time).
#
# How would you find values for $\beta_{0}$ and $\beta_{1}$ such that they minimize the sum of the squared residuals?
#
# Write your answer below.

# %% [markdown]
# #when the derivative is 0, either min or max
# #when second deriv is positive, concave up --> min

# %% [markdown]
# (3e) We take the implicit derivative with respect to the parameter of interest, set it equal to $0$, and solve for the parameter of interest. For exaxmple, the value of the $\beta_{0}$ parameter will be done for you. You will solve for the value of the $\beta_{1}$ parameter (which will use the value of the $\beta_{0}$ parameter in its derivation).
#
# $$ \dfrac{\partial S(\beta_0,\beta_1)}{\partial \beta_0}=\dfrac{\partial}{\partial \beta_1}\sum_{k=1}^m(y^k-\beta_0-\beta_1 x^k)^2=0 \tag{7}$$
# We are only interested in $\beta_0$ so everything else is a “constant” term $c_k=y_k-\beta_1 x_k$.
# $$ \dfrac{\partial}{\partial \beta_0}\sum_{k=1}^m(-\beta_0+y^k-\beta_1 x^k)^2 = \dfrac{\partial}{\partial \beta_0}\sum_{k=1}^m(-\beta_0+c^k)^2=\dfrac{\partial}{\partial \beta_0}\sum_{k=1}^m(\beta_0^2 - 2\beta_0 c^k +{(c^k)}^2)=0 \tag{8}$$
# The derivative of a sum is the sum of the derivative of its summands:
# $$ \sum_{k=1}^m\dfrac{\partial}{\partial \beta_0}(\beta_0^2 - 2\beta_0 c^k + (c^k)^2)=\sum_{k=1}^m (2\beta_0 - 2c^k)=0 \tag{9}$$
# Clean up the sums:
# $$\sum_{k=1}^m (2\beta_0 - 2c^k)=2\sum_{k=1}^m \beta_0 - 2\sum_{k=1}^m c^k=\sum_{k=1}^m \beta_0 - \sum_{k=1}^m c^k=0 \tag{10}$$
# $$ \sum_{k=1}^m \beta_0 - \sum_{k=1}^m c^k=\sum_{k=1}^m \beta_0  - \sum_{k=1}^m(y^k-\beta_1 x^k)=m\beta_0 - \sum_{k=1}^m(y^k-\beta_1 x^k)=0\tag{11}$$
# $$ m\beta_0=\sum_{k=1}^m(y^k-\beta_1 x^k) \tag{12}$$
# Isolate $\beta_{0}$ and call it $\hat\beta_{0}$ because that is our estimate for the parameter.
# $$ \hat\beta_0=\dfrac{ \sum_{k=1}^m y^k-\beta_1\sum_{k=1}^m x^k}{m} \tag{13}$$
# If you want, this can be further simplified to
# $$ \hat\beta_0=\dfrac{ \sum_{k=1}^m y^k}{m}-\beta_1\dfrac{\sum_{k=1}^m x^k}{m}=\bar y - \beta_1 \bar x \tag{14}$$
# where $\bar x$ denotes the average or the mean of the $x$-values.
#
# Ensure that every line in the derivation above makes sense. Perform a similar analysis for the $\beta_{1}$ parameter. Write your answer below for what $\hat\beta_{1}$ equals.

# %% [markdown]
# b1= (sum(xi - x_mean)*(yi - ymean))/sum((xi - x_mean)^2)

# %% [markdown]
# (3f) Convert the definitions for the parameters $\hat\beta_{0}$ and $\hat\beta_{1}$ to Python functions. $\beta_{0}$ is done for you.
#
# Write your code below.

# %%
def beta_1_hat(x,y):
    """
    Input:
    x - list: a list of m x-coordinates
    y - list: a list of m y-coordinates
    Output:
    beta_1 - float: the beta_1 parameter
    """
    ### Write code below ###
    x = np.asarray(x)
    y = np.asarray(y)
    num_sum = 0
    denom_sum = 0
    x_mean = x.mean()
    y_mean = y.mean()
    for i in range(np.size(y)):
        num_sum = num_sum + (x[i]-x_mean)*(y[i]-y_mean)
        denom_sum = denom_sum + (x[i]-x_mean)**2
    beta_1 = num_sum/denom_sum
    ### Write code above ###
    return beta_1

### Don't edit the function below ###
def beta_0_hat(x,y,beta_1):
    """
    Input:
    x - list: a list of m x-coordinates
    y - list: a list of m y-coordinates
    beta_1 - float: the beta_1 parameter
    Output:
    beta_0 - float: the beta_0 parameter
    """
    return (sum(y)/len(y))-beta_1*(sum(x)/len(x))
### Don't edit the function above ###

# %%
### The plotting code below should execute ###
f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    beta_1 = beta_1_hat(x,y)
    beta_0 = beta_0_hat(x,y,beta_1)
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(x, y, edgecolors='k', marker="o", c=colors[i], alpha=2./3)
    tmp_x = np.linspace(0,20)
    # linear regression 
    ax[i].plot(tmp_x, beta_0+beta_1*tmp_x, 'k-', alpha=2./3, label='least squares')    
plt.legend()
plt.tight_layout()
plt.show()
### No changes are required for the plotting code ###

# %% [markdown]
# (3g) Congratulations on your regression! It should make sense to you that regression is just finding the values of the coefficients (the $\beta$ values), that determine the line. Sometimes these $\beta$ values are called _regressors_. These regressors _parameterize_ the regression line. Let's look at the regressors for the four datasets. Find and print out the regressors (the $\beta$ values) for the 4 data sets. Is there anything suspicious about them? Make a connection betwen problem 2 and what you see here. What does this say about the statistics you can calculate about data, and what the data may look like.
#
# Write your code and answers as comments below.

# %%
for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    beta_1 = beta_1_hat(x,y)
    beta_0 = beta_0_hat(x,y,beta_1)
    print(beta_1)
    print(beta_0)
#very similar
# Out:
# 0.5000909090909091
# 3.0000909090909103
# 0.5000000000000001
# 3.00090909090909
# 0.49972727272727274
# 3.0024545454545466
# 0.49990909090909097
# 3.0017272727272717

# %% [markdown]
# (3h) Do you think that your regression did a good job? How would we check? Ideally, we would have more data that represent these four scenarios above, check how close new points are to the lines, and that would be our _error_ (we can also use the data that we trained on to test, but that will be in another assignment). However, we already have some notion of error: our residuals! Let's look at the residuals for each of our data. Remember that the residual is the vertical distance between the line and the data point. For each of the 4 datasets, obtain the list of the residuals. Remember what we said about the residuals in problem (3c). Show the property about the sum of residuals in (3c). Then for each of the lists of the residuals, evaluate the mean. Do the sum and the average of the residuals you've obtained make sense to you?
#
# Write your code and answers as comments below.

# %%
for i in range(4):
    y = list_of_ys[i]
    x = list_of_xs[i]
    beta_1 = beta_1_hat(x,y)
    beta_0 = beta_0_hat(x,y,beta_1)
    resid = []
    resid_sum = 0
    for j in range(np.size(y)):
        new_res = y[j] - (beta_0 + beta_1*x[j])
        resid.append(new_res)
        resid_sum = resid_sum + new_res
    resid = np.asarray(resid)
    
    print(resid)
    print("sum: " + np.str(resid_sum))
    print("mean: " + np.str(resid.mean()))
#makes sense because sum of residuals = 0, and mean is zero because when you add them all up you get zero
# Out:
# [ 0.039      -0.05081818 -1.92127273  1.30909091 -0.17109091 -0.04136364
#   1.23936364 -0.74045455  1.83881818 -1.68072727  0.17945455]
# sum: -1.7763568394002505e-14
# mean: -1.6148698540002276e-15
# [ 1.13909091  1.13909091 -0.76090909  1.26909091  0.75909091 -1.90090909
#   0.12909091 -1.90090909  0.12909091  0.75909091 -0.76090909]
# sum: 1.3322676295501878e-15
# mean: 1.2111523905001707e-16
# [-0.53972727 -0.23027273  3.24109091 -0.39       -0.68945455 -1.15863636
#   0.07918182  0.38863636 -0.84918182 -0.08054545  0.22890909]
# sum: -1.2434497875801753e-14
# mean: -1.1304088978001594e-15
# [-0.421 -1.241  0.709  1.839  1.469  0.039 -1.751  0.    -1.441  0.909
#  -0.111]
# sum: 5.329070518200751e-15
# mean: 4.844609562000683e-16

# %% [markdown]
# (3i) There are clearly some regression lines that fit poorly. Recall the linear regression rests on the assumption that the underlying phenomenon is generating linearly correlated data. For which of the datasets does this assumption seem to fail? Is there a dataset that is not even worth modeling (no inherent relationship between $x$ and $y$)? Is there a dataset that could benefit from having cleaner data (tossing out data that doesn't follow the general trend)?
#
# Write your answer below.

# %% [markdown]
# curved and straight vertical line
# yellow seems useless
# green and yellow have outliers

# %% [markdown]
# (3j) Though the regression may be great fits for some and poor for others, the regression line (as defined by linear least squares) will always go through the mean of the data. Verify this through code.
#
# Write your code and answers as comments below.

# %%
for i in range(4):
    y = list_of_ys[i]
    x = list_of_xs[i]
    beta_1 = beta_1_hat(x,y)
    beta_0 = beta_0_hat(x,y,beta_1)
    y = np.asarray(y)
    x = np.asarray(x)
    print(y.mean())
    print(beta_0 + beta_1*x.mean())
    #assert y.mean() == (beta_0 + beta_1*x.mean())
# Out:
# 7.500909090909093
# 7.500909090909093
# 7.50090909090909
# 7.500909090909091
# 7.5
# 7.500000000000001
# 7.500909090909091
# 7.50090909090909

# %% [markdown]
# ---

# %% [markdown]
# #### 4 General Regression

# %% [markdown]
# (4a) Let's try to prove regression in general. We can start with the same thing we started with in problem 3. Recall that we tried to solve the following system of equations to arrive at values for the $\beta$s. $$\begin{align} \beta_0+\beta_1 x^1 &= y^1 \\ \beta_0+\beta_1 x^2 &= y^2 \\ \vdots \\ \beta_0+\beta_1 x^m &= y^m \end{align} \tag{15}$$ In reality, there is an error term in each equation: $$\begin{align} \beta_0+\beta_1 x^1 +\epsilon^{1} &= y^1 \\ \beta_0+\beta_1 x^2+\epsilon^{2} &= y^2 \\ \vdots \\ \beta_0+\beta_1 x^m+\epsilon^{m} &= y^m \end{align} \tag{16}$$ This is because the line doesn't go through all the points, but rather has some offset $\epsilon$ for each datapoint. What did we call this error or offset in problem 3?
#
# Write your answer below.

# %%
residual

# %% [markdown]
# (4b) The following problems require some experience with linear algebra. Let's convert the system of equations in equation $(16)$ to matrix form. $$\pmatrix{1&x^{1}\\1&x^{2}\\ \vdots&\vdots \\ 1&x^{m}}\pmatrix{\beta_{0} \\ \beta_{1}} +\pmatrix{\epsilon^{1}\\ \epsilon^{2}\\ \vdots \\ \epsilon^{m}}=\pmatrix{y^{1}\\ y^{2}\\ \vdots \\ y^{m}} \tag{17}$$ Verify that this matrix equation is the same as the system of equations in $(16)$. What are the dimensions of each matrix/vector in this equation and how do they relate to the number of variables and the number of data points in our problem?
#
# Write your answer below.

# %% [markdown]
# multiply row by column and then add horizontally

# %% [markdown]
# (4c) Because the actual derivation requires some matrix calculus, the following might look "hand-wavey". For a more rigorous derivation, refer to [Wikipedia](https://en.wikipedia.org/wiki/Linear_regression#Estimation_methods). Let's call the first matrix $X$, the vector of $\beta$s as $\vec\beta$, the vector of $\epsilon$s as $\vec\epsilon$ and the vector of $y$s as $Y$. We can then rewrite $(17)$ as the following: $$X\vec\beta+\vec\epsilon=Y \tag{18}$$ The goal, the same as before, is to obtain the vector $\vec\beta$ such that the error, or the residuals $\vec\epsilon$ is as small possible. Let's make the hand-wavey assumption that the $\vec\epsilon$ should be essentially a vector of ${0}$s. Does this "hand-wavey" assumption make sense given the properties of the residuals we showed in (3i)? $$X\vec\beta=Y \tag{19}$$ First, let's create the $X$ and $Y$ matrices. In Python, anytime we deal with matrices or arrays in any number of dimensions, we'll be using `numpy`. Fill out the following code to create the arrays. Verify that the size of the arrays are as you expected in problem (4b). The asserts that I've written for you should pass.
#
# Write your code and answers as comments below.

# %%
list_of_Y_vecs = []
list_of_X_arrs = []

for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    m = len(y)
    # firstly, create the column vector for Y using numpy
    # recall that Y should be of shape (m,1)
    # that is, it should have m rows
    # and 1 column
    ### Write code below ###
    Y_vec = np.zeros((m,1))
    for i in range(m):
        Y_vec[i][0] = y[i]
    ### Write code above ###
    assert Y_vec.shape[0] == m
    assert Y_vec.shape[1] == 1
    
    # secondly, create the matrix for X using numpy
    # recall that X should be of shape (m,2)
    # that is, it should have m rows
    # and 2 columns
    # the first column should be all 1s
    ### Write code below ###
    X_arr = np.zeros((m,2))
    for i in range(m):
        X_arr[i][0] = 1
        X_arr[i][1] = x[i]
    ### Write code above ###
    assert X_arr.shape[0] == m
    assert X_arr.shape[1] == 2
    assert np.allclose(X_arr[:,0],np.ones((m)))
    
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_Y_vecs.append(Y_vec)
    list_of_X_arrs.append(X_arr)

# %% [markdown]
# (4d) How can we use arrays to solve for the vector of regressors? We can take the inverse. Use `np.linalg.solve` and input the $X$ and $Y$ matrices as arguments. Is your code passing? Can we take the inverse of $X$? What are some requirements to take the inverse of a matrix?
#
# Write your code and answers as comments below.

# %%
for i in range(4):
    X_arr = list_of_X_arrs[i]
    Y_vec = list_of_Y_vecs[i]
    # use np.linalg.solve to solve X*betas=Y
    ### Write code below ###
    np.linalg.solve(X_arr,Y_vec)
    ### Write code above ###
#no because not square matrices, ie. can't take inverse
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-56-60318859c91b> in <module>
#       4     # use np.linalg.solve to solve X*betas=Y
#       5     ### Write code below ###
# ----> 6     np.linalg.solve(X_arr,Y_vec)
#       7     ### Write code above ###
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     388     a, _ = _makearray(a)
#     389     _assertRankAtLeast2(a)
# --> 390     _assertNdSquareness(a)
#     391     b, wrap = _makearray(b)
#     392     t, result_t = _commonType(a, b)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assertNdSquareness(*arrays)
#     211         m, n = a.shape[-2:]
#     212         if m != n:
# --> 213             raise LinAlgError('Last 2 dimensions of the array must be square')
#     214
# ...

# %% [markdown]
# (4e) Your code above should not have passed because $X$ is not a square matrix; that is, it has more rows than it has columns. We can solve this by left multiplying the matrix equation in $(19)$ with $X^{\intercal}$, the transpose of the $X$ matrix. Our new matrix equation is then the following: $$X^{\intercal}X\vec\beta=X^{\intercal}Y\tag{20}$$ I will calculate the transpose of $X$ for you, and the quantities of $X^{\intercal}X$ and $X^{\intercal}Y$. Note my use of `np.matmul` to calculate these. Write an assert that checks if  $X^{\intercal}X$ is a square matrix. Check the size of resulting vector $X^{\intercal}Y$ and compare it to the size of the vector $Y$. Is this expected? Write asserts for this as well. Write similar asserts to what I've written in (4c).
#
# Write your code below.

# %%
list_of_XTY_vecs = []
list_of_XTX_arrs = []

for i in range(4):
    X_arr = list_of_X_arrs[i]
    Y_vec = list_of_Y_vecs[i]
    # transposing a numpy array is extremely easy
    # taking matrix multiplication is also straight-
    # forward with numpy
    XTX = np.matmul(X_arr.T,X_arr)
    XTY = np.matmul(X_arr.T,Y_vec)
    # write asserts for what you think the shapes
    # of these matrices should be
    ### Write asserts below ###
    assert XTX.shape[0] == XTX.shape[1]
    assert XTY.shape[0] == 2
    assert XTY.shape[1] == 1   
    ### Write asserts above ###
        
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_XTX_arrs.append(XTX)
    list_of_XTY_vecs.append(XTY)

# %% [markdown]
# (4g) Because the matrix multiplying $\vec\beta$ is now square, we can take the inverse of it, and left-multiply both sides of the equation with its inverse, which yields the following: $$\vec\beta=(X^{\intercal}X)^{-1}X^{\intercal}Y\tag{21}$$ Fill out the following code similar to (4d). The plotting will be done automatically. Compare the results that you see here to the results that you've obtained in problem 3. Are the regressors the same? Are the lines the same?
#
# Write your code and answers as comments below.

# %%
betas_vec =[]
for i in range(4):
    XTX = list_of_XTX_arrs[i]
    XTY = list_of_XTY_vecs[i]
    # use np.linalg.solve to solve (X.T*X)*betas=(X.T*Y)
    ### Write code below ###
    betas = np.linalg.solve(XTX,XTY)
    ### Write code above ###
    betas_vec.append(betas)

# %%
### The plotting code below should execute ###
f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    beta_1 = betas_vec[i][1]
    beta_0 = betas_vec[i][0]
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(x, y, edgecolors='k', marker="o", c=colors[i], alpha=2./3)
    tmp_x = np.linspace(0,20)
    # linear regression 
    ax[i].plot(tmp_x, beta_0+beta_1*tmp_x, 'k-', alpha=2./3, label='least squares')    
plt.legend()
plt.tight_layout()
plt.show()
### No changes are required for the plotting code ###

# %% [markdown]
# (4h) The reason for using this matrix approach is that we no longer have to deal with individual components, such as solving for the individual regressors manually, as we did in problem 3. We can also deal with higher dimensional data much more easily (data with more features or more data points), as we'll see in a later problem. For now, let's consider adding another _feature_. Features can be thought of as columns in our $X$ matrix. Recall that our rows represent the individual sample data points. Adding more features can give us more information about the problem and uncover hidden relationships. For example, if our target (our $Y$) was the price of a company stock, then the features could be the company's revenue, the number of mentions in the news, the number of employees it hires, etc. Another way adding features can help is by identifying nonlinear relationships. For example, our only feature right now is the $x$-coordinate. However, another feature we could add is the square of the $x$-coordinate. If we look at the system of equations from $(2)$ and add another feature such as the square of the first feature, we would get something like the following: $$\begin{align} \beta_0+\beta_1 x^1+\beta_2 (x^1)^{2} &= y^1 \\ \beta_0+\beta_1 x^2+\beta_2 (x^2)^{2} &= y^2 \\ \vdots \\ \beta_0+\beta_1 x^m +\beta_2 (x^m)^{2} &= y^m \end{align} \tag{22}$$ However, even though the system of equations is the same, the matrix equation from $(21)$ still solves this for us. Explain why below. Talk about the dimensions (number of rows and columns) of $X$, $\vec\beta$, and $Y$. What dimension stays the same if we keep the same number of data points. What dimension changed when we increased the number of features. What is the relationship between the number of features and the number of regressors? What would the equation similar to equation $(17)$ look like for this problem.
#
# Write your answer below. No code required.

# %% [markdown]
# x matrix would be m by 3 instead. Can still take transpose and make square and then take inverse. Very versatile

# %% [markdown]
# (4i) Let's implement this. This is called _quadratic regression_ and in general, adding features that build a _polynomial_ (an equation based on the linear combination of the powers of the first feature (the $x$-coordinate)) is called _polynomial regression_. First build the $X$-matrix. Use your answer from the previous problem to help you through this. Then solve for the regressors. Fill in the code below. The asserts I've written should pass. You are encouraged to write your own asserts as well. I have written the plotting code as well, but note how I draw the linear regression line.
#
# Write your code below.

# %%
list_of_X_arrs = []

for i in range(4):
    x = list_of_xs[i]
    m = len(x)
    
    # create the matrix for X using numpy
    # recall that X should be of shape (m,3)
    # that is, it should have m rows
    # and 3 columns
    # the first column should be all 1s
    # the second column should be x
    # the third column should be the square of x
    ### Write code below ###
    X_arr = np.zeros((m,3))
    for i in range(m):
        X_arr[i][0] = 1
        X_arr[i][1] = x[i]
        X_arr[i][2] = (x[i])**2
    ### Write code above ###
    assert X_arr.shape[0] == m
    assert X_arr.shape[1] == 3
    assert np.allclose(X_arr[:,0],np.ones((m)))
    assert np.allclose(X_arr[:,1], np.array(x))
    
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_X_arrs.append(X_arr)
    # This code does not need to be edited

list_of_XTY_vecs = []
list_of_XTX_arrs = []

for i in range(4):
    X_arr = list_of_X_arrs[i]
    Y_vec = list_of_Y_vecs[i]
    # transposing a numpy array is extremely easy
    # taking matrix multiplication is also straight-
    # forward with numpy
    XTX = np.matmul(X_arr.T,X_arr)
    XTY = np.matmul(X_arr.T,Y_vec)
    # write asserts for what you think the shapes
    # of these matrices should be
    ### Write asserts below ###
    assert XTX.shape[0] == XTX.shape[1]
    assert XTY.shape[0] == 3
    assert XTY.shape[1] == 1 
    ### Write asserts above ###
        
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_XTX_arrs.append(XTX)
    list_of_XTY_vecs.append(XTY)

betas_vec =[]
for i in range(4):
    XTX = list_of_XTX_arrs[i]
    XTY = list_of_XTY_vecs[i]
    # use np.linalg.solve to solve (X.T*X)*betas=(X.T*Y)
    ### Write code below ###
    betas = np.linalg.solve(XTX,XTY)
    ### Write code above ###
    betas_vec.append(betas)

# %%
### The plotting code below should execute ###
f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    beta_2 = betas_vec[i][2]
    beta_1 = betas_vec[i][1]
    beta_0 = betas_vec[i][0]
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(x, y, edgecolors='k', marker="o", c=colors[i], alpha=2./3)
    tmp_x = np.linspace(0,20)
    # linear regression 
    ax[i].plot(tmp_x, beta_0+beta_1*tmp_x+beta_2*(tmp_x**2), 'k-', alpha=2./3, label='least squares')    
plt.legend()
plt.tight_layout()
plt.show()
### No changes are required for the plotting code ###

# %% [markdown]
# (4j) What do you notice about the quadratic regression? Does it match your expectations for what it should do? How does it perform on ones that we thought were already good fits (datasets in which we thought linear regression provided a good fit)? Define the following terms:
# 1. Model complexity
# 2. Underfitting and Overfitting
# 3. Bias-Variance tradeoff
# 3. Generalization (in the context of machine learning algorithms)
#
# Draw connections between your linear regression model and your quadratic regression model and the terms you've defined above.
#
# Write your answer below.

# %% [markdown]
# much better

# %% [markdown]
# (4k) Predict what happens if we tried to fit a fifth order polynomial (finding optimal values for $\beta_{0},\beta_{1},\beta_{2},\beta_{3},\beta_{4},\beta_{5}$ and the features are the $x$-coordinate, the square of the $x$-coordinate, the cube of the $x$-coordinate, the fourth power of the $x$-coordinate, and the fifth power of the $x$-coordinate) to the dataset. Is this high model-complexity or low model-complexity (what is the relationship between the number of regressors or features we have to the model complexity)? In what ways would the fit of the 5th order model be better? Does it generalize better or worse than models of different complexity? Would this model overfit or underfit to the data?
#
# Write your answer below.

# %% [markdown]
# much better, higher dinmension better

# %% [markdown]
# (4l) Fit a fifth order polynomial to the datasets using everything you've learned above. Feel free to copy blocks of code (the code-blocks from (4i)), but make sure to rewrite the comments and the asserts and some of the code that builds the $X$ matrix. The block of code that plots is almost done, but make sure that you get the regressors from the list of $\beta$ vectors for the dataset and then change how the line is drawn. Look at the other plotting code blocks to figure out what's happening. Do the results you obtain match your predictions in (4k)?
#
# Write your code and answers as comments below.

# %%
list_of_X_arrs = []

for i in range(4):
    x = list_of_xs[i]
    m = len(x)
    
    # create the matrix for X using numpy
    # recall that X should be of shape (m,3)
    # that is, it should have m rows
    # and 3 columns
    # the first column should be all 1s
    # the second column should be x
    # the third column should be the square of x
    ### Write code below ###
    X_arr = np.zeros((m,5))
    for i in range(m):
        X_arr[i][0] = 1
        X_arr[i][1] = x[i]
        X_arr[i][2] = (x[i])**2
        X_arr[i][3] = (x[i])**3
        X_arr[i][4] = (x[i])**4
    ### Write code above ###
    assert X_arr.shape[0] == m
    assert X_arr.shape[1] == 5
    assert np.allclose(X_arr[:,0],np.ones((m)))
    assert np.allclose(X_arr[:,1], np.array(x))
    
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_X_arrs.append(X_arr)
    # This code does not need to be edited

list_of_XTY_vecs = []
list_of_XTX_arrs = []

for i in range(4):
    X_arr = list_of_X_arrs[i]
    Y_vec = list_of_Y_vecs[i]
    # transposing a numpy array is extremely easy
    # taking matrix multiplication is also straight-
    # forward with numpy
    XTX = np.matmul(X_arr.T,X_arr)
    XTY = np.matmul(X_arr.T,Y_vec)
    # write asserts for what you think the shapes
    # of these matrices should be
    ### Write asserts below ###
    assert XTX.shape[0] == XTX.shape[1]
    assert XTY.shape[0] == 5
    assert XTY.shape[1] == 1 
    ### Write asserts above ###
        
    # Adding arrays to lists
    # This code does not need to be edited
    list_of_XTX_arrs.append(XTX)
    list_of_XTY_vecs.append(XTY)

betas_vec =[]
for i in range(4):
    XTX = list_of_XTX_arrs[i]
    XTY = list_of_XTY_vecs[i]
    # use np.linalg.solve to solve (X.T*X)*betas=(X.T*Y)
    ### Write code below ###
    betas = np.linalg.solve(XTX,XTY)
    ### Write code above ###
    betas_vec.append(betas)

# %%
### The plotting code below should execute ###
f1 = plt.figure(dpi=250)
# Make grid
gridd=(2,2)
gs1 = gridspec.GridSpec(*gridd)
# Get list of axis objects
ax = [f1.add_subplot(gs1[x]) for x in range(gridd[0] * gridd[1])]
# Plot
for i in range(4):
    x = list_of_xs[i]
    y = list_of_ys[i]
    beta_4 = betas_vec[i][4]
    beta_3 = betas_vec[i][3]
    beta_2 = betas_vec[i][2]
    beta_1 = betas_vec[i][1]
    beta_0 = betas_vec[i][0]
    ax[i].set_xlim([0,20])
    ax[i].set_ylim([0,15])
    ax[i].scatter(x, y, edgecolors='k', marker="o", c=colors[i], alpha=2./3)
    tmp_x = np.linspace(0,20)
    # linear regression 
    ax[i].plot(tmp_x, beta_0+beta_1*tmp_x+beta_2*(tmp_x**2) + beta_3*(tmp_x**3) + beta_4*(tmp_x**4), 'k-', alpha=2./3, label='least squares')    
plt.legend()
plt.tight_layout()
plt.show()
### No changes are required for the plotting code ###

# %%
good fit
